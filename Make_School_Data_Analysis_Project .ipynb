# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import glob
import os
import sys
from collections import OrderedDict
# %matplotlib inline
np.random.seed(1547)


#import blob to make reading of files in easier
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 361D-A6A7
#
#  Directory of C:\Users\Don\Desktop\github\DS-1-Data-Analysis\datasets\SA Feedback Surveys_FINAL
#
# 02/05/2018  12:12 PM    <DIR>          .
# 02/05/2018  12:12 PM    <DIR>          ..
# 02/05/2018  12:12 PM            10,244 .DS_Store
# 02/05/2018  12:12 PM    <DIR>          2016
# 02/05/2018  12:12 PM    <DIR>          2017
# 02/05/2018  12:12 PM             1,810 output_filename_version2.csv
#                2 File(s)         12,054 bytes
#                4 Dir(s)  78,931,886,080 bytes free

# %%
for name in glob.glob('2017/Student Feedback Surveys-Superview.csv'):
    print (name)
# Out:
# 2017/Student Feedback Surveys-Superview.csv

# %%
for name in glob.glob('2016/*'):
    print (name)
# Out:
# 2016\Anon Week 1 Feedback - LA.csv
# 2016\Anon Week 1 Feedback - NY.csv
# 2016\Anon Week 1 Feedback - SF.csv
# 2016\Anon Week 1 Feedback - Singapore.csv
# 2016\Anon Week 1 Feedback - SV.csv
# 2016\Anon Week 2 Feedback - LA.csv
# 2016\Anon Week 2 Feedback - NY.csv
# 2016\Anon Week 2 Feedback - SF.csv
# 2016\Anon Week 2 Feedback - SG.csv
# 2016\Anon Week 2 Feedback - SV.csv
# 2016\Anon Week 3 Feedback - LA.csv
# 2016\Anon Week 3 Feedback - NY.csv
# 2016\Anon Week 3 Feedback - SF.csv
# 2016\Anon Week 3 Feedback - SG.csv
# 2016\Anon Week 3 Feedback - SV.csv
# 2016\Anon Week 4 Feedback - LA.csv
# 2016\Anon Week 4 Feedback - NY.csv
# 2016\Anon Week 4 Feedback - SF.csv
# 2016\Anon Week 4 Feedback - SG.csv
# 2016\Anon Week 4 Feedback - SV.csv
# 2016\Anon Week 5 Feedback - HK.csv
# 2016\Anon Week 5 Feedback - LA.csv
# 2016\Anon Week 5 Feedback - NY.csv
# 2016\Anon Week 5 Feedback - SF.csv
# 2016\Anon Week 5 Feedback - SG.csv
# 2016\Anon Week 5 Feedback - SV.csv
# 2016\Anon Week 6 Feedback - HK.csv
# 2016\Anon Week 6 Feedback - LA.csv
# 2016\Anon Week 6 Feedback - NY.csv
# 2016\Anon Week 6 Feedback - SF.csv
# 2016\Anon Week 6 Feedback - SG.csv
# 2016\Anon Week 6 Feedback - SV.csv
# 2016\Anon Week 6 Feedback - Taipei.csv
# 2016\Anon Week 6 Feedback - Tokyo.csv
# 2016\Anon Week 7 Feedback - LA.csv
# 2016\Anon Week 7 Feedback - NY.csv
# 2016\Anon Week 7 Feedback - SF.csv
# 2016\Anon Week 7 Feedback - SV.csv
# 2016\Anon Week 7 Feedback - Taipei.csv
# 2016\Week 8 Feedback (2016, incomplete) - results.csv

# %%
list_all_week =[]

for i in range(1,8):
    list_file = []
    city = ""
    for name in glob.glob('./Anon Week ' + str(i) + "*"):
        city = name[-6:-4]
        df = pd.read_csv(name)
        if city == "re" or city == 'SG':
            city = "Singapore"
        elif city == "yo":
            city = "Tokyo"
        elif city == "ei":
            city = "Taipei"
        elif city == 'LA':
            city = 'Los Angeles'
        elif city == 'SF':
            city = "San Francisco"
        elif city == 'NY':
            city = 'New York City'
        elif city == 'SV':
            city = 'Sunnyvale'
        elif city == 'HK':
            city = 'Hong Kong'
        df["Location"] = city
        list_file.append(df)
    df_2016 = pd.concat(list_file)
    df_2016["Week"] = i
    list_all_week.append(df_2016)
df_2016 = pd.concat(list_all_week)
df_2016

# %%
print(glob.glob('2017/Student Feedback Surveys-Superview.csv'))
# Out:
# ['2017/Student Feedback Surveys-Superview.csv']

# %%
MS2017_data_df= pd.read_csv('2017/Student Feedback Surveys-Superview.csv')
MS2017_data_df
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# 14     299  Washington DC   Apps, Explorer  Week 1            5
# 15     307            NaN              NaN  Week 3            5
# 16     319   Redwood City             Apps  Week 3            5
# 17     336  New York City             Apps  Week 1            5
# 18     441  San Francisco   Apps, Explorer  Week 3            5
# 19     482    Santa Clara             Apps  Week 3            5
# 20      37    Los Angeles            Games  Week 1            6
# 21      41        Chicago   Apps, Explorer  Week 1            6
# 22      45        Chicago             Apps  Week 1            6
# 23      47        Chicago             Apps  Week 1            6
# 24      77  San Francisco             Apps  Week 1            6
# 25      78  San Francisco             Apps  Week 1            6
# 26      94  San Francisco   Apps, Explorer  Week 1            6
# 27     193    Santa Clara             Apps  Week 2            6
# 28     251  San Francisco   Apps, Explorer  Week 2            6
# 29     254  San Francisco             Apps  Week 2            6
# ...    ...            ...              ...     ...          ...
# 1423  1470  New York City            Games  Week 7           10
# 1424  1471  New York City             Apps  Week 7            8
# 1425  1472  New York City            Games  Week 7            9
# 1426  1473  New York City  Games, Explorer  Week 7           10
# 1427  1474  New York City            Games  Week 7            9
# 1428  1475  New York City             Apps  Week 7            9
# 1429  1476  New York City             Apps  Week 7            8
# 1430  1477  New York City            Games  Week 7           10
# 1431  1478  New York City             Apps  Week 7           10
# 1432  1479  New York City            Games  Week 7            9
# 1433  1480  New York City             Apps  Week 7            9
# 1434  1481  New York City             Apps  Week 7           10
# 1435  1482  New York City             Apps  Week 7            8
# 1436  1483  New York City             Apps  Week 7            7
# 1437  1484  New York City   Apps, Explorer  Week 7            7
# 1438  1485  New York City             Apps  Week 7            7
# 1439  1486  New York City             Apps  Week 7            9
# 1440  1487  New York City             Apps  Week 7            8
# 1441  1488  New York City  Games, Explorer  Week 7            7
# 1442  1489  New York City   Apps, Explorer  Week 7           10
# 1443  1490  New York City   Apps, Explorer  Week 7           10
# 1444  1491  New York City            Games  Week 7            9
# 1445  1492  New York City             Apps  Week 7            9
# 1446  1493  New York City             Apps  Week 7            3
# 1447  1494  New York City  Games, Explorer  Week 7           10
# 1448  1495  New York City   Apps, Explorer  Week 7           10
# 1449  1496  New York City   Apps, Explorer  Week 7            8
# 1450  1497  New York City             Apps  Week 7           10
# 1451  1498  New York City   Apps, Explorer  Week 7            1
# 1452  1499  New York City             Apps  Week 5            8
#
#         Schedule Pacing
# 0            Just right
# 1     A little too fast
# 2          Way too slow
# 3     A little too fast
# 4            Just right
# 5            Just right
# 6            Just right
# 7     A little too slow
# 8     A little too slow
# 9            Just right
# 10           Just right
# 11           Just right
# 12         Way too fast
# 13           Just right
# 14    A little too slow
# 15    A little too slow
# 16           Just right
# 17    A little too slow
# 18           Just right
# 19           Just right
# 20           Just right
# 21           Just right
# 22    A little too slow
# 23    A little too slow
# 24    A little too fast
# 25    A little too fast
# 26           Just right
# 27           Just right
# 28           Just right
# 29         Way too fast
# ...                 ...
# 1423         Just right
# 1424         Just right
# 1425         Just right
# 1426         Just right
# 1427         Just right
# 1428         Just right
# 1429  A little too fast
# 1430         Just right
# 1431         Just right
# 1432         Just right
# 1433         Just right
# 1434         Just right
# 1435         Just right
# 1436  A little too fast
# 1437       Way too fast
# 1438         Just right
# 1439         Just right
# 1440         Just right
# 1441         Just right
# 1442         Just right
# 1443         Just right
# 1444  A little too fast
# 1445         Just right
# 1446         Just right
# 1447         Just right
# 1448         Just right
# 1449         Just right
# 1450         Just right
# 1451  A little too slow
# 1452         Just right
#
# [1453 rows x 6 columns]

# %%
#investigationg head and tail for EOF Errora
MS2017_data_df.head()
MS2017_data_df.tail()
# Out:
#         ID       Location           Track    Week Rating (Num)  \
# 1448  1495  New York City  Apps, Explorer  Week 7           10
# 1449  1496  New York City  Apps, Explorer  Week 7            8
# 1450  1497  New York City            Apps  Week 7           10
# 1451  1498  New York City  Apps, Explorer  Week 7            1
# 1452  1499  New York City            Apps  Week 5            8
#
#         Schedule Pacing
# 1448         Just right
# 1449         Just right
# 1450         Just right
# 1451  A little too slow
# 1452         Just right

# %%
# Beginning of globbing files for the 2016 folders... T_T;;
#MS2016_data_df= pd.read_csv('2016/Anon Week 7 Feedback - Taipei.csv')
#MS2016_data_df

# %%
# will take all of the 2016 files ( yes i know theyre un sorted) and put them into one giant file, as a test for later interations
files = sorted(glob.iglob('2016/*.csv'))
header = OrderedDict()
data = []
for filename in files:
    with open(filename, 'r') as fin:
        csvin = csv.DictReader(fin)
        header.update(OrderedDict.fromkeys(csvin.fieldnames))
        data.append(next(csvin))
with open('output_filename_version2.csv', 'w', newline='') as fout:
    csvout = csv.DictWriter(fout, fieldnames=list(header))
    csvout.writeheader()
    csvout.writerows(data)

# %%
# failed attempt but keeping code to frankenstien it in a later interations
MS2016_data_df= pd.read_csv('output_filename_version2.csv')
MS2016_data_df
# Out:
#              Timestamp  \
# 0   6/23/2016 15:55:12
# 1    6/24/2016 7:03:34
# 2   6/24/2016 14:02:56
# 3                  NaN
# 4   6/23/2016 22:24:53
# 5   6/30/2016 14:09:14
# 6     7/1/2016 6:41:31
# 7    7/1/2016 16:35:14
# 8     7/1/2016 5:41:15
# 9    7/1/2016 13:27:56
# 10   7/8/2016 10:31:27
# 11    7/8/2016 6:21:11
# 12   7/8/2016 15:56:20
# 13    7/8/2016 7:36:11
# 14   7/8/2016 12:52:08
# 15  7/15/2016 13:20:35
# 16   7/15/2016 6:28:26
# 17  7/15/2016 15:26:38
# 18   7/15/2016 2:45:00
# 19  7/15/2016 13:30:19
# 20  7/21/2016 21:57:59
# 21  7/22/2016 16:15:37
# 22  7/22/2016 13:29:33
# 23                 NaN
# 24   7/22/2016 1:30:17
# 25  7/22/2016 12:52:43
# 26   7/29/2016 0:19:08
# 27   7/31/2016 8:43:57
# 28   7/29/2016 6:54:22
# 29  7/29/2016 15:17:19
# 30  7/29/2016 19:18:44
# 31  7/29/2016 13:46:28
# 32   7/29/2016 1:07:23
# 33   7/31/2016 1:04:57
# 34   8/5/2016 11:22:50
# 35   8/5/2016 12:34:16
# 36   8/5/2016 11:13:01
# 37   8/5/2016 13:37:43
# 38    8/5/2016 1:39:41
# 39                 NaN
#
#     How would you rate your overall satisfaction with the Summer Academy this week?  \
# 0                                                 3.0
# 1                                                 3.0
# 2                                                 3.0
# 3                                                 2.0
# 4                                                 2.0
# 5                                                 4.0
# 6                                                 3.0
# 7                                                 2.0
# 8                                                 4.0
# 9                                                 3.0
# 10                                                4.0
# 11                                                4.0
# 12                                                3.0
# 13                                                4.0
# 14                                                5.0
# 15                                                5.0
# 16                                                5.0
# 17                                                5.0
# 18                                                4.0
# 19                                                2.0
# 20                                                4.0
# 21                                                3.0
# 22                                                5.0
# 23                                                3.0
# 24                                                4.0
# 25                                                4.0
# 26                                                5.0
# 27                                                5.0
# 28                                                2.0
# 29                                                4.0
# 30                                                4.0
# 31                                                4.0
# 32                                                5.0
# 33                                                3.0
# 34                                                3.0
# 35                                                3.0
# 36                                                5.0
# 37                                                3.0
# 38                                                3.0
# 39                                                NaN
#
#     How well are the tutorials paced? What track are you in?  \
# 0                                 4.0                    NaN
# 1                                 5.0                  Games
# 2                                 2.0                   Apps
# 3                                 4.0                  Games
# 4                                 3.0                    NaN
# 5                                 NaN                    NaN
# 6                                 NaN                   Apps
# 7                                 NaN                   Apps
# 8                                 NaN                    NaN
# 9                                 NaN                   Apps
# 10                                NaN                    NaN
# 11                                NaN                   Apps
# 12                                NaN                   Apps
# 13                                NaN                    NaN
# 14                                NaN                  Games
# 15                                NaN                    NaN
# 16                                NaN                   Apps
# 17                                NaN                   Apps
# 18                                NaN                    NaN
# 19                                NaN                   Apps
# 20                                3.0                    NaN
# 21                                NaN                  Games
# 22                                NaN                   Apps
# 23                                NaN                   Apps
# 24                                NaN                    NaN
# 25                                NaN                   Apps
# 26                                NaN                    NaN
# 27                                NaN                  Games
# 28                                NaN                   Apps
# 29                                NaN                   Apps
# 30                                NaN                    NaN
# 31                                NaN                   Apps
# 32                                NaN                    NaN
# 33                                NaN                    NaN
# 34                                NaN                  Intro
# 35                                NaN                   Apps
# 36                                NaN                   Apps
# 37                                NaN                   Apps
# 38                                NaN                    NaN
# 39                                NaN                    NaN
#
#             Unnamed: 4  How well is the schedule paced?  \
# 0                  NaN                              NaN
# 1                  NaN                              NaN
# 2                  NaN                              NaN
# 3   6/24/2016 13:32:01                              NaN
# 4                  NaN                              NaN
# 5                  NaN                              2.0
# 6                  NaN                              2.0
# 7                  NaN                              3.0
# 8                  NaN                              3.0
# 9                  NaN                              4.0
# 10                 NaN                              2.0
# 11                 NaN                              3.0
# 12                 NaN                              2.0
# 13                 NaN                              3.0
# 14                 NaN                              2.0
# 15                 NaN                              3.0
# 16                 NaN                              3.0
# 17                 NaN                              3.0
# 18                 NaN                              3.0
# 19                 NaN                              1.0
# 20                 NaN                              NaN
# 21                 NaN                              2.0
# 22                 NaN                              5.0
# 23                 NaN                              3.0
# 24                 NaN                              3.0
# 25                 NaN                              3.0
# 26                 NaN                              3.0
# 27                 NaN                              3.0
# 28                 NaN                              2.0
# 29                 NaN                              3.0
# 30                 NaN                              3.0
# 31                 NaN                              3.0
# 32                 NaN                              3.0
# 33                 NaN                              4.0
# 34                 NaN                              2.0
# 35                 NaN                              3.0
# 36                 NaN                              5.0
# 37                 NaN                              3.0
# 38                 NaN                              3.0
# 39                 NaN                              NaN
#
#                                    #  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# 30                               NaN
# 31                               NaN
# 32                               NaN
# 33                               NaN
# 34                               NaN
# 35                               NaN
# 36                               NaN
# 37                               NaN
# 38                               NaN
# 39  00b836bda84e6bdbe780af97e249e59f
#
#     How likely is it that you would recommend the Make School Summer Academy to a friend?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                               10.0
#
#     location       track Start Date (UTC) Submit Date (UTC)  Network ID
# 0        NaN         NaN              NaN               NaN         NaN
# 1        NaN         NaN              NaN               NaN         NaN
# 2        NaN         NaN              NaN               NaN         NaN
# 3        NaN         NaN              NaN               NaN         NaN
# 4        NaN         NaN              NaN               NaN         NaN
# 5        NaN         NaN              NaN               NaN         NaN
# 6        NaN         NaN              NaN               NaN         NaN
# 7        NaN         NaN              NaN               NaN         NaN
# 8        NaN         NaN              NaN               NaN         NaN
# 9        NaN         NaN              NaN               NaN         NaN
# 10       NaN         NaN              NaN               NaN         NaN
# 11       NaN         NaN              NaN               NaN         NaN
# 12       NaN         NaN              NaN               NaN         NaN
# 13       NaN         NaN              NaN               NaN         NaN
# 14       NaN         NaN              NaN               NaN         NaN
# 15       NaN         NaN              NaN               NaN         NaN
# 16       NaN         NaN              NaN               NaN         NaN
# 17       NaN         NaN              NaN               NaN         NaN
# 18       NaN         NaN              NaN               NaN         NaN
# 19       NaN         NaN              NaN               NaN         NaN
# 20       NaN         NaN              NaN               NaN         NaN
# 21       NaN         NaN              NaN               NaN         NaN
# 22       NaN         NaN              NaN               NaN         NaN
# 23       NaN         NaN              NaN               NaN         NaN
# 24       NaN         NaN              NaN               NaN         NaN
# 25       NaN         NaN              NaN               NaN         NaN
# 26       NaN         NaN              NaN               NaN         NaN
# 27       NaN         NaN              NaN               NaN         NaN
# 28       NaN         NaN              NaN               NaN         NaN
# 29       NaN         NaN              NaN               NaN         NaN
# 30       NaN         NaN              NaN               NaN         NaN
# 31       NaN         NaN              NaN               NaN         NaN
# 32       NaN         NaN              NaN               NaN         NaN
# 33       NaN         NaN              NaN               NaN         NaN
# 34       NaN         NaN              NaN               NaN         NaN
# 35       NaN         NaN              NaN               NaN         NaN
# 36       NaN         NaN              NaN               NaN         NaN
# 37       NaN         NaN              NaN               NaN         NaN
# 38       NaN         NaN              NaN               NaN         NaN
# 39  New York  summerApps      9/7/16 1:03       9/7/16 1:04  3212b7a834

# %%
#worked with several students to get this corrent and now submitting ( got the most help from jsutin since he's on my core project team,
#figuring out how to get the other cities, singapore might give me the most trouble)
file_dir = 'datasets/ms_survey_feedback/2016/'

#Get all files except for wierdy week 8 one
filenames = glob.glob(file_dir + 'Anon Week * Feedback - *.csv')


#Get wierdy week 8 file
week_8 = glob.glob(file_dir + '*Week 8*')
w8_df = pd.read_csv(week_8[0])

#instantiate list to append columns to
col_number = list()
col_headers = list()

#Create list of column names to extract from filenames
df_2016 = pd.DataFrame([])
list_2016 = list()
print("number of files:", len(filenames))
week_set = set()
city_set = set()
for file_name in filenames:
    rows = list()
    file_data = file_name.split(" ")
    week = file_data[2]
    city_list = file_data[-1].split('.')
    city = city_list[0]
    file_df = pd.read_csv(file_name)
    
    week_set.add(week)
    city_set.add(city)
    
    week_data = list()
    city_data = list()

    for _ in range(0, len(file_df)):
        week_data.append(week)
        city_data.append(city)

    file_df["Week"] = week_data
    file_df["City"] = city_data
    list_2016.append(file_df)
    
df_2016 = pd.concat(list_2016)

display(df_2016)
