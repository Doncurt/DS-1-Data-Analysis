# %% [markdown]
# # California 2016 Law Enforcement Statistics

# %% [markdown]
# ### Author : Donovan Adams
# ### DS-1 Q3 2018

# %% [markdown]
# ## Part 1 Descriptive Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import glob
import os
import sys
# %matplotlib inline
np.random.seed(1547)


for name in glob.glob('datasets\california crime\*'):
    print (name)
# Out:
# datasets\california crime\citizen_complaints_2016.csv
# datasets\california crime\citizen_complaints_readme.pdf
# datasets\california crime\crime_codes.csv
# datasets\california crime\deaths_in_custody.csv
# datasets\california crime\law_enforcement_officers_killed_2000-2016.csv
# datasets\california crime\law_enforcement_officers_killed_readme.pdf
# datasets\california crime\old_format_citizen_complaints_1981-2016.csv
# datasets\california crime\ruse_of_force_2016.csv
# datasets\california crime\ruse_of_force_agency_names.csv
# datasets\california crime\ruse_of_force_civilian_officer.csv
# datasets\california crime\use_of_force_16_report.pdf

# %%
df_all_deaths_in_custody = pd.read_csv('datasets\california crime\deaths_in_custody.csv')
df_all_deaths_in_custody
# Out:
#       record_key_number reporting_agency agency_number  \
# 0               2005001            State        27025C
# 1               2005002           Police        390200
# 2               2005003            State        48015C
# 3               2005004            State        15025C
# 4               2005005            State        34065C
# 5               2005006            State        48015C
# 6               2005007            State        36015C
# 7               2005008            State        16045C
# 8               2005009            State        18035C
# 9               2005010          Sheriff        090000
# 10              2005011            State        48015C
# 11              2005012            State        15045C
# 12              2005013          Sheriff        190000
# 13              2005014            State        16045C
# 14              2005015            State        48015C
# 15              2005016            State        48015C
# ...

# %%
df_citizen_complaints_2016= pd.read_csv('datasets\california crime\citizen_complaints_2016.csv')

df_citizen_complaints_2016
# Out:
#      NCIC                                         AgencyName  ComplaintYear  \
# 0    0100                Alameda County Sheriff's Department           2016
# 1    0101                          Alameda Police Department           2016
# 2    0102                           Albany Police Department           2016
# 3    0103                         Berkeley Police Department           2016
# 4    0104                       Emeryville Police Department           2016
# 5    0105                          Fremont Police Department           2016
# 6    0106                          Hayward Police Department           2016
# 7    0107                        Livermore Police Department           2016
# 8    0108                           Newark Police Department           2016
# 9    0109                          Oakland Police Department           2016
# 10   0110                         Piedmont Police Department           2016
# ...

# %%
df_use_of_force_2016 = pd.read_csv('datasets\california crime\ruse_of_force_agency_names.csv')
df_use_of_force_2016
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-70-c103bed4b403> in <module>()
# ----> 1 df_use_of_force_2016 = pd.read_csv('datasets\california crime\ruse_of_force_agency_names.csv')
#       2 df_use_of_force_2016
#
# ...

# %%
df_crime_codes = pd.read_csv('datasets\california crime\crime_codes.csv')
df_crime_codes
#this data unfortunately cant be uses with the following sets due to there being no coades attached to the data
#citizen complaints in 2016
#
# Out:
#      offense_code    summary_code       summary_offense_type  \
# 0               1              68                    Truancy
# 1               1              68                    Truancy
# 2               2              69                    Runaway
# 3               2              69                    Runaway
# 4               3              70                     Curfew
# 5               3              70                     Curfew
# 6               4              72        Other Stat Offenses
# 7               4              72        Other Stat Offenses
# 8               6              72        Other Stat Offenses
# 9               6              72        Other Stat Offenses
# 10              7              71               Incorrigible
# 11              7              71               Incorrigible
# 12              9              72        Other Stat Offenses
# 13              9              72        Other Stat Offenses
# ...
